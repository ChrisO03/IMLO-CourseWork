# %%
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms


import numpy as np
import matplotlib.pyplot as plt
import scipy
from PIL import Image

from google.colab import runtime

# %%
#Hyperparameters
lr = 0.00005 #Drop this down, too high
momentum = 0 #default = 0
weight_decay = 0.05 #default = 0
dampening = 0 #default = 0

#Other
batch_size = 64
epochs = 50

# %%
transforms = {
    'train':
    #Composing several transforms together
    transforms.Compose(
        [
            transforms.RandomRotation(degrees=15),
            transforms.RandomHorizontalFlip(),
            transforms.RandomVerticalFlip(),
            transforms.ColorJitter(),
            transforms.GaussianBlur(1),
            transforms.RandomAdjustSharpness(1),
            transforms.RandomPerspective(),
            transforms.ToTensor(), #To tensor object
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)), #Mean = 0.5, std = 0.5
            transforms.Resize((256,256)) #Speeds up model without losing too much information
        ]),

    'trainOld':
    transforms.Compose(
        [
            transforms.TrivialAugmentWide(),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
            transforms.Resize((256,256)),
        ]
    ),

    'val':
    transforms.Compose(
        [
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
            transforms.Resize((256,256))
        ]),

    'test':
    transforms.Compose(
        [
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
            transforms.Resize((256,256))
        ])
}

# %%
train_data = datasets.Flowers102(root='./data', split='train', transform=transforms['train'], download=True)
train_dataloader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                          shuffle=True)

# %%
val_data = datasets.Flowers102(root='./data', split='val', transform=transforms['val'], download=False)
val_dataloader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=False)

# %%
test_data = datasets.Flowers102(root='./data', split='test', transform=transforms['test'], download=False)
test_dataloader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=False)

# %%
#dataloaders = {
#    'train': train_dataloader,
#    'val': val_dataloader
#}

# %%
# Show the images in the batch to see what the transforms are doing to them
def imshow(img):
  img = img / 2 + 0.5 # unnormalize
  npimg = img.numpy() # convert to numpy objects
  plt.imshow(np.transpose(npimg, (1, 2, 0)))
  plt.show()

dataiter = iter(train_dataloader)
for i in range(1):
  images, lbls = next(dataiter)
  imshow(torchvision.utils.make_grid(images))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
#Architecture inspired by https://poloclub.github.io/cnn-explainer/#article-input
#and PyTorch for Deep Learning & Machine Learning – Full Course by freeCodeCamp.org https://www.youtube.com/watch?v=V_xro1bcAuA
class CNNv1(nn.Module):
  def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
    super().__init__()
    #Block is comprised of multiple layers
    self.conv_block_1 = nn.Sequential(
        #Conv layer to extract features
        nn.Conv2d(in_channels=input_shape,
                  out_channels=hidden_units,
                  kernel_size=3, #Size of the kernel it looks at
                  stride=1, #How far it steps between kernels
                  padding=1), #Added to the edges to stop the miage decreasing in size
        nn.ReLU(),
        nn.Conv2d(in_channels=hidden_units,
                  out_channels=hidden_units,
                  kernel_size=3,
                  stride=1,
                  padding=1),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2)
    )
    self.conv_block_2 = nn.Sequential(
        nn.Conv2d(in_channels=hidden_units,
                  out_channels=hidden_units,
                  kernel_size=3,
                  stride=1,
                  padding=1),
         nn.ReLU(),
         nn.Conv2d(in_channels=hidden_units,
                  out_channels=hidden_units,
                  kernel_size=3,
                  stride=1,
                  padding=1),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2)
    )
    self.classifier = nn.Sequential(
        nn.Flatten(),
        nn.Linear(in_features=hidden_units*64*64,
                  out_features=output_shape)
    )

  def forward(self, x):
    x = self.conv_block_1(x)
    #print(x.shape)
    x = self.conv_block_2(x)
    #print(x.shape)
    x = self.classifier(x)
    return x

# %%
model = CNNv1(input_shape=3,
              hidden_units=102,
              output_shape=102).to(device)
print(model)
# Out:
# CNNv1(
#   (conv_block_1): Sequential(
#     (0): Conv2d(3, 102, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(102, 102, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_2): Sequential(
#     (0): Conv2d(102, 102, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(102, 102, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=417792, out_features=102, bias=True)
#   )
# )

# %%
#Loss function and optimiser
loss_fn = nn.CrossEntropyLoss()
#optimiser = torch.optim.SGD(model.parameters(),
#                            lr=lr,
#                            momentum=momentum,
#                            weight_decay=weight_decay,
#                            dampening=dampening)
optimiser = torch.optim.Adam(model.parameters(),
                             lr=lr,
                             weight_decay=weight_decay)

# %%
#Train the model using the training data
def train(dataloader, model, loss_fn, optimiser):
  size = len(dataloader.dataset)
  batches = len(dataloader)
  model.train()
  running_loss, running_corrects = 0, 0

  for batch, (X, y) in enumerate(dataloader):
    X, y = X.to(device), y.to(device)

    # Compute prediction error
    pred = model(X)
    loss = loss_fn(pred, y)

    running_loss += loss
    running_corrects += torch.count_nonzero(pred.argmax(1)==y)

    # Backpropagation
    loss.backward()
    optimiser.step()
    optimiser.zero_grad()

  ave_loss = running_loss/batches
  corrects = running_corrects/size

  print(f"Train Error: \nAccuracy: {(100*corrects):.2f}%, Avg loss: {ave_loss:.6f} \n")

  return ave_loss, corrects

# %%
#Validate the models progress using the validation data
def valTest(dataloader, model, loss_fn, split):
  size = len(dataloader.dataset)
  batches = len(dataloader)
  model.eval()
  running_loss, running_corrects = 0, 0

  with torch.inference_mode():
    for X, y in dataloader:
      X, y = X.to(device), y.to(device)
      pred = model(X)
      loss = loss_fn(pred,y)

      running_loss += loss
      running_corrects += torch.count_nonzero(pred.argmax(1)==y)

  ave_loss = running_loss/batches
  corrects = running_corrects/size

  print(f"{split} Error: \n Accuracy: {(100*corrects):.2f}%, Avg loss: {ave_loss:.6f} \n")

  return ave_loss, corrects

# %%
def pltHist(hist):
  plt.figure(figsize=(17,5))
  plt.subplot(121)
  plt.plot(hist['train_loss'],'-o')
  plt.plot(hist['val_loss'],'-o')
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.legend(['Train','Val'])
  plt.title('Train vs Validation loss')

  plt.subplot(122)
  plt.plot(hist['train_accuracy'],'-o')
  plt.plot(hist['val_accuracy'],'-o')
  plt.xlabel('epoch')
  plt.ylabel('Accuracy')
  plt.legend(['Train','Val'])
  plt.title('Train vs Validation Accuracy')

# %%
def trainValLoop(model, loss_fn, optimiser, epochs):
  train_loss_hist = []
  train_acc_hist = []
  val_loss_hist = []
  val_acc_hist = []

  for epoch in range(epochs):
    print(f"Epoch {epoch+1}/{epochs} -------------------------------")
    train_loss, train_acc = train(train_dataloader, model, loss_fn, optimiser)
    val_loss, val_acc = valTest(val_dataloader, model, loss_fn, 'Validate')

    train_loss_hist.append(train_loss.cpu().detach().numpy())
    train_acc_hist.append(train_acc.cpu().cpu().detach().numpy())
    val_loss_hist.append(val_loss.cpu().detach().numpy())
    val_acc_hist.append(val_acc.cpu().detach().numpy())

  hist = {'train_loss':train_loss_hist, 'train_accuracy':train_acc_hist,
          'val_loss':val_loss_hist, 'val_accuracy':val_acc_hist}
  pltHist(hist)
  valTest(test_dataloader, model, loss_fn, 'Test')

# %%
trainValLoop(model, loss_fn, optimiser, epochs)
# Out:
# Epoch 1/50 -------------------------------
# Train Error:
# Accuracy: 0.88%, Avg loss: 4.704351
#
# Validate Error:
#  Accuracy: 2.25%, Avg loss: 4.584977
#
# Epoch 2/50 -------------------------------
# Train Error:
# Accuracy: 2.65%, Avg loss: 4.544371
#
# Validate Error:
#  Accuracy: 3.53%, Avg loss: 4.392839
#
# Epoch 3/50 -------------------------------
# Train Error:
# Accuracy: 4.22%, Avg loss: 4.259292
#
# Validate Error:
#  Accuracy: 6.08%, Avg loss: 4.025815
#
# Epoch 4/50 -------------------------------
# Train Error:
# Accuracy: 9.80%, Avg loss: 3.885076
#
# Validate Error:
#  Accuracy: 10.98%, Avg loss: 3.788266
#
# Epoch 5/50 -------------------------------
# Train Error:
# Accuracy: 14.22%, Avg loss: 3.566371
#
# Validate Error:
#  Accuracy: 13.82%, Avg loss: 3.682198
#
# Epoch 6/50 -------------------------------
# Train Error:
# Accuracy: 18.43%, Avg loss: 3.375417
#
# Validate Error:
#  Accuracy: 15.29%, Avg loss: 3.618714
#
# Epoch 7/50 -------------------------------
# Train Error:
# Accuracy: 20.39%, Avg loss: 3.216539
#
# Validate Error:
#  Accuracy: 18.63%, Avg loss: 3.520964
#
# Epoch 8/50 -------------------------------
# Train Error:
# Accuracy: 22.65%, Avg loss: 3.097651
#
# Validate Error:
#  Accuracy: 15.69%, Avg loss: 3.644523
#
# Epoch 9/50 -------------------------------
# Train Error:
# Accuracy: 26.08%, Avg loss: 3.028368
#
# Validate Error:
#  Accuracy: 20.39%, Avg loss: 3.507215
#
# Epoch 10/50 -------------------------------
# Train Error:
# Accuracy: 25.10%, Avg loss: 2.944063
#
# Validate Error:
#  Accuracy: 20.39%, Avg loss: 3.548949
#
# Epoch 11/50 -------------------------------
# Train Error:
# Accuracy: 28.43%, Avg loss: 2.857477
#
# Validate Error:
#  Accuracy: 22.06%, Avg loss: 3.488027
#
# Epoch 12/50 -------------------------------
# Train Error:
# Accuracy: 29.71%, Avg loss: 2.750699
#
# Validate Error:
#  Accuracy: 21.76%, Avg loss: 3.559228
#
# Epoch 13/50 -------------------------------
# Train Error:
# Accuracy: 32.35%, Avg loss: 2.626515
#
# Validate Error:
#  Accuracy: 21.18%, Avg loss: 3.544091
#
# Epoch 14/50 -------------------------------
# Train Error:
# Accuracy: 32.65%, Avg loss: 2.602663
#
# Validate Error:
#  Accuracy: 21.57%, Avg loss: 3.535341
#
# Epoch 15/50 -------------------------------
# Train Error:
# Accuracy: 34.90%, Avg loss: 2.579049
#
# Validate Error:
#  Accuracy: 20.00%, Avg loss: 3.521413
#
# Epoch 16/50 -------------------------------
# Train Error:
# Accuracy: 36.47%, Avg loss: 2.467363
#
# Validate Error:
#  Accuracy: 21.08%, Avg loss: 3.606107
#
# Epoch 17/50 -------------------------------
# Train Error:
# Accuracy: 37.35%, Avg loss: 2.412610
#
# Validate Error:
#  Accuracy: 20.98%, Avg loss: 3.597326
#
# Epoch 18/50 -------------------------------
# Train Error:
# Accuracy: 38.92%, Avg loss: 2.339056
#
# Validate Error:
#  Accuracy: 21.86%, Avg loss: 3.609741
#
# Epoch 19/50 -------------------------------
# Train Error:
# Accuracy: 39.71%, Avg loss: 2.337870
#
# Validate Error:
#  Accuracy: 22.06%, Avg loss: 3.628337
#
# Epoch 20/50 -------------------------------
# Train Error:
# Accuracy: 38.33%, Avg loss: 2.309200
#
# Validate Error:
#  Accuracy: 22.65%, Avg loss: 3.740947
#
# Epoch 21/50 -------------------------------
# Train Error:
# Accuracy: 41.27%, Avg loss: 2.255104
#
# Validate Error:
#  Accuracy: 22.16%, Avg loss: 3.677162
#
# Epoch 22/50 -------------------------------
# Train Error:
# Accuracy: 43.53%, Avg loss: 2.125205
#
# Validate Error:
#  Accuracy: 24.12%, Avg loss: 3.656970
#
# Epoch 23/50 -------------------------------
# Train Error:
# Accuracy: 45.69%, Avg loss: 2.074073
#
# Validate Error:
#  Accuracy: 22.55%, Avg loss: 3.800330
#
# Epoch 24/50 -------------------------------
# Train Error:
# Accuracy: 46.27%, Avg loss: 2.113308
#
# Validate Error:
#  Accuracy: 26.18%, Avg loss: 3.671271
#
# Epoch 25/50 -------------------------------
# Train Error:
# Accuracy: 45.59%, Avg loss: 2.097126
#
# Validate Error:
#  Accuracy: 25.00%, Avg loss: 3.644979
#
# Epoch 26/50 -------------------------------
# Train Error:
# Accuracy: 45.00%, Avg loss: 2.028142
#
# Validate Error:
#  Accuracy: 24.71%, Avg loss: 3.605813
#
# Epoch 27/50 -------------------------------
# Train Error:
# Accuracy: 47.65%, Avg loss: 1.981064
#
# Validate Error:
#  Accuracy: 26.27%, Avg loss: 3.760604
#
# Epoch 28/50 -------------------------------
# Train Error:
# Accuracy: 46.76%, Avg loss: 1.971833
#
# Validate Error:
#  Accuracy: 23.92%, Avg loss: 3.776466
#
# Epoch 29/50 -------------------------------
# Train Error:
# Accuracy: 47.84%, Avg loss: 1.960289
#
# Validate Error:
#  Accuracy: 26.76%, Avg loss: 3.611177
#
# Epoch 30/50 -------------------------------
# Train Error:
# Accuracy: 50.29%, Avg loss: 1.896577
#
# Validate Error:
#  Accuracy: 26.18%, Avg loss: 3.706022
#
# Epoch 31/50 -------------------------------
# Train Error:
# Accuracy: 51.18%, Avg loss: 1.859208
#
# Validate Error:
#  Accuracy: 26.57%, Avg loss: 3.772295
#
# Epoch 32/50 -------------------------------
# Train Error:
# Accuracy: 49.22%, Avg loss: 1.859893
#
# Validate Error:
#  Accuracy: 26.57%, Avg loss: 3.650258
#
# Epoch 33/50 -------------------------------
# Train Error:
# Accuracy: 53.43%, Avg loss: 1.787379
#
# Validate Error:
#  Accuracy: 28.14%, Avg loss: 3.832464
#
# Epoch 34/50 -------------------------------
# Train Error:
# Accuracy: 50.29%, Avg loss: 1.816714
#
# Validate Error:
#  Accuracy: 27.35%, Avg loss: 3.789358
#
# Epoch 35/50 -------------------------------
# Train Error:
# Accuracy: 52.75%, Avg loss: 1.755203
#
# Validate Error:
#  Accuracy: 26.67%, Avg loss: 3.714783
#
# Epoch 36/50 -------------------------------
# Train Error:
# Accuracy: 53.04%, Avg loss: 1.690681
#
# Validate Error:
#  Accuracy: 28.14%, Avg loss: 3.884900
#
# Epoch 37/50 -------------------------------
# Train Error:
# Accuracy: 55.78%, Avg loss: 1.691234
#
# Validate Error:
#  Accuracy: 26.37%, Avg loss: 3.794330
#
# Epoch 38/50 -------------------------------
# Train Error:
# Accuracy: 56.86%, Avg loss: 1.583886
#
# Validate Error:
#  Accuracy: 28.33%, Avg loss: 3.858418
#
# Epoch 39/50 -------------------------------
# Train Error:
# Accuracy: 56.37%, Avg loss: 1.602425
#
# Validate Error:
#  Accuracy: 26.76%, Avg loss: 3.885795
#
# Epoch 40/50 -------------------------------
# Train Error:
# Accuracy: 56.76%, Avg loss: 1.616832
#
# Validate Error:
#  Accuracy: 28.53%, Avg loss: 3.866826
#
# Epoch 41/50 -------------------------------
# Train Error:
# Accuracy: 58.14%, Avg loss: 1.572837
#
# Validate Error:
#  Accuracy: 28.82%, Avg loss: 3.884047
#
# Epoch 42/50 -------------------------------
# Train Error:
# Accuracy: 57.55%, Avg loss: 1.579137
#
# Validate Error:
#  Accuracy: 27.06%, Avg loss: 3.954113
#
# Epoch 43/50 -------------------------------
# Train Error:
# Accuracy: 57.16%, Avg loss: 1.604323
#
# Validate Error:
#  Accuracy: 29.02%, Avg loss: 3.889349
#
# Epoch 44/50 -------------------------------
# Train Error:
# Accuracy: 56.57%, Avg loss: 1.535935
#
# Validate Error:
#  Accuracy: 28.43%, Avg loss: 3.918985
#
# Epoch 45/50 -------------------------------
# Train Error:
# Accuracy: 58.33%, Avg loss: 1.517288
#
# Validate Error:
#  Accuracy: 28.14%, Avg loss: 3.906013
#
# Epoch 46/50 -------------------------------
# Train Error:
# Accuracy: 59.80%, Avg loss: 1.431315
#
# Validate Error:
#  Accuracy: 27.84%, Avg loss: 3.946963
#
# Epoch 47/50 -------------------------------
# Train Error:
# Accuracy: 59.90%, Avg loss: 1.468567
#
# Validate Error:
#  Accuracy: 29.02%, Avg loss: 3.960785
#
# Epoch 48/50 -------------------------------
# Train Error:
# Accuracy: 63.92%, Avg loss: 1.355155
#
# Validate Error:
#  Accuracy: 25.10%, Avg loss: 4.021790
#
# Epoch 49/50 -------------------------------
# Train Error:
# Accuracy: 61.96%, Avg loss: 1.383463
#
# Validate Error:
#  Accuracy: 27.35%, Avg loss: 4.073363
#
# Epoch 50/50 -------------------------------
# Train Error:
# Accuracy: 60.29%, Avg loss: 1.457193
#
# Validate Error:
#  Accuracy: 28.92%, Avg loss: 3.987140
#
# Test Error:
#  Accuracy: 26.07%, Avg loss: 4.474733

# %%
PATH = './CNNv1.pth'
torch.save(model.state_dict(), PATH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d4185f9c1651> in <cell line: 2>()
#       1 PATH = './CNNv1.pth'
# ----> 2 torch.save(model.state_dict(), PATH)
#
# NameError: name 'torch' is not defined

# %%
#Stops Google stealing my credits
#runtime.unassign()
