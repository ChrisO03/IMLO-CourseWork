# %%
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms


import numpy as np
import matplotlib.pyplot as plt
import scipy
from PIL import Image

from google.colab import runtime

# %%
#Hyperparameters
lr = 0.0001 #Drop this down, too high
momentum = 0 #default = 0
weight_decay = 0 #default = 0
dampening = 0 #default = 0

#Other
batch_size = 64
epochs = 25

# %%
transforms = {
    'train':
    transforms.Compose( #Composing several transforms together
    [transforms.ToTensor(), #To tensor object
     transforms.RandomRotation(degrees=15),
     transforms.RandomHorizontalFlip(),
     transforms.ColorJitter(),
     transforms.GaussianBlur(3),
     transforms.RandomAdjustSharpness(3),
     transforms.RandomPerspective(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)), #Mean = 0.5, std = 0.5
     transforms.Resize((256,256)) #Speeds up model without losing too much information
     ]),

    'val':
    transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
     transforms.Resize((256,256))
     ]),

    'test':
    transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
     transforms.Resize((256,256))
     ])
}

# %%
train_data = datasets.Flowers102(root='./data', split='train', transform=transforms['train'], download=True)
train_dataloader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                          shuffle=True)
# Out:
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/102flowers.tgz to data/flowers-102/102flowers.tgz
# 100%|██████████| 344862509/344862509 [00:28<00:00, 11977751.24it/s]
# Extracting data/flowers-102/102flowers.tgz to data/flowers-102
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/imagelabels.mat to data/flowers-102/imagelabels.mat
# 100%|██████████| 502/502 [00:00<00:00, 639787.48it/s]
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/setid.mat to data/flowers-102/setid.mat
# 100%|██████████| 14989/14989 [00:00<00:00, 15185609.34it/s]

# %%
val_data = datasets.Flowers102(root='./data', split='val', transform=transforms['val'], download=False)
val_dataloader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=False)

# %%
test_data = datasets.Flowers102(root='./data', split='test', transform=transforms['test'], download=False)
test_dataloader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=False)

# %%
dataloaders = {
    'train': train_dataloader,
    'val': val_dataloader
}

# %%
# Show the images in the batch to see what the transforms are doing to them
def imshow(img):
  img = img / 2 + 0.5 # unnormalize
  npimg = img.numpy() # convert to numpy objects
  plt.imshow(np.transpose(npimg, (1, 2, 0)))
  plt.show()

dataiter = iter(train_dataloader)
for i in range(1):
  images, lbls = next(dataiter)
  imshow(torchvision.utils.make_grid(images))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
#Architecture inspired by https://poloclub.github.io/cnn-explainer/#article-input
#and PyTorch for Deep Learning & Machine Learning – Full Course by freeCodeCamp.org https://www.youtube.com/watch?v=V_xro1bcAuA
class CNNv1(nn.Module):
  def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
    super().__init__()
    #Block is comprised of multiple layers
    self.conv_block_1 = nn.Sequential(
        #Conv layer to extract features
        nn.Conv2d(in_channels=input_shape,
                  out_channels=hidden_units,
                  kernel_size=3, #Size of the kernel it looks at
                  stride=1, #How far it steps between kernels
                  padding=1), #Added to the edges to stop the miage decreasing in size
        nn.ReLU(),
        nn.Conv2d(in_channels=hidden_units,
                  out_channels=hidden_units,
                  kernel_size=3,
                  stride=1,
                  padding=1),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2)
    )
    self.conv_block_2 = nn.Sequential(
        nn.Conv2d(in_channels=hidden_units,
                  out_channels=hidden_units,
                  kernel_size=3,
                  stride=1,
                  padding=1),
         nn.ReLU(),
         nn.Conv2d(in_channels=hidden_units,
                  out_channels=hidden_units,
                  kernel_size=3,
                  stride=1,
                  padding=1),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2)
    )
    self.classifier = nn.Sequential(
        nn.Flatten(),
        nn.Linear(in_features=hidden_units*64*64,
                  out_features=output_shape)
    )

  def forward(self, x):
    x = self.conv_block_1(x)
    #print(x.shape)
    x = self.conv_block_2(x)
    #print(x.shape)
    x = self.classifier(x)
    return x

# %%
model = CNNv1(input_shape=3,
              hidden_units=102,
              output_shape=102).to(device)
print(model)
# Out:
# CNNv1(
#   (conv_block_1): Sequential(
#     (0): Conv2d(3, 102, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(102, 102, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_2): Sequential(
#     (0): Conv2d(102, 102, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(102, 102, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=417792, out_features=102, bias=True)
#   )
# )

# %%
#Loss function and optimiser
loss_fn = nn.CrossEntropyLoss()
#optimiser = torch.optim.SGD(model.parameters(),
#                            lr=lr,
#                            momentum=momentum,
#                            weight_decay=weight_decay,
#                            dampening=dampening)
optimiser = torch.optim.Adam(model.parameters(),
                             lr=lr,
                             weight_decay=weight_decay)

# %%
#Train the model using the training data
def train(dataloader, model, loss_fn, optimiser):
  size = len(dataloader.dataset)
  batches = len(dataloader)
  model.train()
  running_loss, running_corrects = 0, 0

  for batch, (X, y) in enumerate(dataloader):
    X, y = X.to(device), y.to(device)

    # Compute prediction error
    pred = model(X)
    loss = loss_fn(pred, y)

    running_loss += loss
    running_corrects += torch.count_nonzero(pred.argmax(1)==y)

    # Backpropagation
    loss.backward()
    optimiser.step()
    optimiser.zero_grad()

  ave_loss = running_loss/batches
  corrects = running_corrects/size

  print(f"Train Error: \nAccuracy: {(100*corrects):.2f}%, Avg loss: {ave_loss:.6f} \n")

  return ave_loss, corrects

# %%
#Validate the models progress using the validation data
def valTest(dataloader, model, loss_fn, split):
  size = len(dataloader.dataset)
  batches = len(dataloader)
  model.eval()
  running_loss, running_corrects = 0, 0

  with torch.inference_mode():
    for X, y in dataloader:
      X, y = X.to(device), y.to(device)
      pred = model(X)
      loss = loss_fn(pred,y)

      running_loss += loss
      running_corrects += torch.count_nonzero(pred.argmax(1)==y)

  ave_loss = running_loss/batches
  corrects = running_corrects/size

  print(f"{split} Error: \n Accuracy: {(100*corrects):.2f}%, Avg loss: {ave_loss:.6f} \n")

  return ave_loss, corrects

# %%
def pltHist(hist):
  plt.figure(figsize=(17,5))
  plt.subplot(121)
  plt.plot(hist['train_loss'],'-o')
  plt.plot(hist['val_loss'],'-o')
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.legend(['Train','Val'])
  plt.title('Train vs Validation loss')

  plt.subplot(122)
  plt.plot(hist['train_accuracy'],'-o')
  plt.plot(hist['val_accuracy'],'-o')
  plt.xlabel('epoch')
  plt.ylabel('Accuracy')
  plt.legend(['Train','Val'])
  plt.title('Train vs Validation Accuracy')

# %%
def trainValLoop(dataloaders, model, loss_fn, optimiser, epochs):
  train_loss_hist = []
  train_acc_hist = []
  val_loss_hist = []
  val_acc_hist = []

  for epoch in range(epochs):
    print(f"Epoch {epoch+1}/{epochs} -------------------------------")
    train_loss, train_acc = train(train_dataloader, model, loss_fn, optimiser)
    val_loss, val_acc = valTest(val_dataloader, model, loss_fn, 'Validate')

    train_loss_hist.append(train_loss.cpu().detach().numpy())
    train_acc_hist.append(train_acc.cpu().cpu().detach().numpy())
    val_loss_hist.append(val_loss.cpu().detach().numpy())
    val_acc_hist.append(val_acc.cpu().detach().numpy())

  hist = {'train_loss':train_loss_hist, 'train_accuracy':train_acc_hist,
          'val_loss':val_loss_hist, 'val_accuracy':val_acc_hist}
  pltHist(hist)
  valTest(val_dataloader, model, loss_fn, 'Test')

# %%
trainValLoop(dataloaders, model, loss_fn, optimiser, epochs)
# Out:
# Epoch 1/25 -------------------------------
# Train Error:
# Accuracy: 0.69%, Avg loss: 4.716768
#
# Validate Error:
#  Accuracy: 4.02%, Avg loss: 4.524292
#
# Epoch 2/25 -------------------------------
# Train Error:
# Accuracy: 3.63%, Avg loss: 4.342936
#
# Validate Error:
#  Accuracy: 6.96%, Avg loss: 4.060537
#
# Epoch 3/25 -------------------------------
# Train Error:
# Accuracy: 11.27%, Avg loss: 3.778634
#
# Validate Error:
#  Accuracy: 10.69%, Avg loss: 3.802360
#
# Epoch 4/25 -------------------------------
# Train Error:
# Accuracy: 20.00%, Avg loss: 3.323969
#
# Validate Error:
#  Accuracy: 16.67%, Avg loss: 3.694821
#
# Epoch 5/25 -------------------------------
# Train Error:
# Accuracy: 30.69%, Avg loss: 2.837482
#
# Validate Error:
#  Accuracy: 20.49%, Avg loss: 3.681170
#
# Epoch 6/25 -------------------------------
# Train Error:
# Accuracy: 34.22%, Avg loss: 2.561854
#
# Validate Error:
#  Accuracy: 23.04%, Avg loss: 3.627515
#
# Epoch 7/25 -------------------------------
# Train Error:
# Accuracy: 39.90%, Avg loss: 2.343148
#
# Validate Error:
#  Accuracy: 25.78%, Avg loss: 3.655224
#
# Epoch 8/25 -------------------------------
# Train Error:
# Accuracy: 44.12%, Avg loss: 2.152237
#
# Validate Error:
#  Accuracy: 26.18%, Avg loss: 3.639661
#
# Epoch 9/25 -------------------------------
# Train Error:
# Accuracy: 46.96%, Avg loss: 2.078179
#
# Validate Error:
#  Accuracy: 26.96%, Avg loss: 3.722086
#
# Epoch 10/25 -------------------------------
# Train Error:
# Accuracy: 52.35%, Avg loss: 1.879532
#
# Validate Error:
#  Accuracy: 27.35%, Avg loss: 3.777293
#
# Epoch 11/25 -------------------------------
# Train Error:
# Accuracy: 55.59%, Avg loss: 1.645453
#
# Validate Error:
#  Accuracy: 28.43%, Avg loss: 3.976280
#
# Epoch 12/25 -------------------------------
# Train Error:
# Accuracy: 57.75%, Avg loss: 1.528087
#
# Validate Error:
#  Accuracy: 28.92%, Avg loss: 4.127488
#
# Epoch 13/25 -------------------------------
# Train Error:
# Accuracy: 58.33%, Avg loss: 1.509159
#
# Validate Error:
#  Accuracy: 27.55%, Avg loss: 4.222332
#
# Epoch 14/25 -------------------------------
# Train Error:
# Accuracy: 62.55%, Avg loss: 1.401398
#
# Validate Error:
#  Accuracy: 30.59%, Avg loss: 4.198082
#
# Epoch 15/25 -------------------------------
# Train Error:
# Accuracy: 64.71%, Avg loss: 1.296818
#
# Validate Error:
#  Accuracy: 30.69%, Avg loss: 4.479232
#
# Epoch 16/25 -------------------------------
# Train Error:
# Accuracy: 65.20%, Avg loss: 1.241493
#
# Validate Error:
#  Accuracy: 30.88%, Avg loss: 4.397089
#
# Epoch 17/25 -------------------------------
# Train Error:
# Accuracy: 68.33%, Avg loss: 1.160872
#
# Validate Error:
#  Accuracy: 28.33%, Avg loss: 4.548173
#
# Epoch 18/25 -------------------------------
# Train Error:
# Accuracy: 67.65%, Avg loss: 1.122946
#
# Validate Error:
#  Accuracy: 29.02%, Avg loss: 4.832788
#
# Epoch 19/25 -------------------------------
# Train Error:
# Accuracy: 68.92%, Avg loss: 1.100349
#
# Validate Error:
#  Accuracy: 29.71%, Avg loss: 4.646134
#
# Epoch 20/25 -------------------------------
# Train Error:
# Accuracy: 68.73%, Avg loss: 1.042496
#
# Validate Error:
#  Accuracy: 29.51%, Avg loss: 4.938475
#
# Epoch 21/25 -------------------------------
# Train Error:
# Accuracy: 71.96%, Avg loss: 0.988261
#
# Validate Error:
#  Accuracy: 31.08%, Avg loss: 4.657232
#
# Epoch 22/25 -------------------------------
# Train Error:
# Accuracy: 74.61%, Avg loss: 0.913325
#
# Validate Error:
#  Accuracy: 29.71%, Avg loss: 4.979613
#
# Epoch 23/25 -------------------------------
# Train Error:
# Accuracy: 75.88%, Avg loss: 0.870641
#
# Validate Error:
#  Accuracy: 28.53%, Avg loss: 5.099998
#
# Epoch 24/25 -------------------------------
# Train Error:
# Accuracy: 75.98%, Avg loss: 0.856918
#
# Validate Error:
#  Accuracy: 31.47%, Avg loss: 5.039974
#
# Epoch 25/25 -------------------------------
# Train Error:
# Accuracy: 76.96%, Avg loss: 0.838075
#
# Validate Error:
#  Accuracy: 29.31%, Avg loss: 5.172847
#
# Test Error:
#  Accuracy: 29.31%, Avg loss: 5.172847

# %%
#Stops Google stealing my credits
#runtime.unassign()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-10c6a500dc76> in <cell line: 2>()
#       1 #Stops Google stealing my credits
# ----> 2 runtime.unassign()
#
# NameError: name 'runtime' is not defined
