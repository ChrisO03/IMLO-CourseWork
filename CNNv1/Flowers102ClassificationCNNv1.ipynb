# %%
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms


import numpy as np
import matplotlib.pyplot as plt
import scipy
from PIL import Image

from google.colab import runtime

# %%
#Hyperparameters
lr = 0.00005 #Drop this down, too high
momentum = 0 #default = 0
weight_decay = 0.05 #default = 0
dampening = 0 #default = 0

#Other
batch_size = 64
epochs = 50

# %%
transforms = {
    'trainOld':
    #Composing several transforms together
    transforms.Compose(
        [
            transforms.RandomRotation(degrees=15),
            transforms.RandomHorizontalFlip(),
            transforms.RandomVerticalFlip(),
            transforms.ColorJitter(),
            transforms.GaussianBlur(1),
            transforms.RandomAdjustSharpness(1),
            transforms.RandomPerspective(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)), #Mean = 0.5, std = 0.5
            transforms.Resize((256,256)), #Speeds up model without losing too much information
            transforms.ToTensor() #To tensor object
        ]),

    'train':
    transforms.Compose(
        [
            transforms.TrivialAugmentWide(),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
            transforms.Resize((256,256)),
        ]
    ),

    'val':
    transforms.Compose(
        [
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
            transforms.Resize((256,256))
        ]),

    'test':
    transforms.Compose(
        [
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
            transforms.Resize((256,256))
        ])
}

# %%
train_data = datasets.Flowers102(root='./data', split='train', transform=transforms['train'], download=True)
train_dataloader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
                                          shuffle=True)
# Out:
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/102flowers.tgz to data/flowers-102/102flowers.tgz
# 100%|██████████| 344862509/344862509 [00:28<00:00, 12178280.67it/s]
# Extracting data/flowers-102/102flowers.tgz to data/flowers-102
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/imagelabels.mat to data/flowers-102/imagelabels.mat
# 100%|██████████| 502/502 [00:00<00:00, 797553.26it/s]
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/setid.mat to data/flowers-102/setid.mat
# 100%|██████████| 14989/14989 [00:00<00:00, 21146459.02it/s]

# %%
val_data = datasets.Flowers102(root='./data', split='val', transform=transforms['val'], download=False)
val_dataloader = torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=False)

# %%
test_data = datasets.Flowers102(root='./data', split='test', transform=transforms['test'], download=False)
test_dataloader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=False)

# %%
#dataloaders = {
#    'train': train_dataloader,
#    'val': val_dataloader
#}

# %%
# Show the images in the batch to see what the transforms are doing to them
def imshow(img):
  img = img / 2 + 0.5 # unnormalize
  npimg = img.numpy() # convert to numpy objects
  plt.imshow(np.transpose(npimg, (1, 2, 0)))
  plt.show()

dataiter = iter(train_dataloader)
for i in range(1):
  images, lbls = next(dataiter)
  imshow(torchvision.utils.make_grid(images))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
#Architecture inspired by https://poloclub.github.io/cnn-explainer/#article-input
#and PyTorch for Deep Learning & Machine Learning – Full Course by freeCodeCamp.org https://www.youtube.com/watch?v=V_xro1bcAuA
class CNNv1(nn.Module):
  def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
    super().__init__()
    #Block is comprised of multiple layers
    self.conv_block_1 = nn.Sequential(
        #Conv layer to extract features
        nn.Conv2d(in_channels=input_shape,
                  out_channels=hidden_units,
                  kernel_size=3, #Size of the kernel it looks at
                  stride=1, #How far it steps between kernels
                  padding=1), #Added to the edges to stop the miage decreasing in size
        nn.ReLU(),
        nn.Conv2d(in_channels=hidden_units,
                  out_channels=hidden_units,
                  kernel_size=3,
                  stride=1,
                  padding=1),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2)
    )
    self.conv_block_2 = nn.Sequential(
        nn.Conv2d(in_channels=hidden_units,
                  out_channels=hidden_units,
                  kernel_size=3,
                  stride=1,
                  padding=1),
         nn.ReLU(),
         nn.Conv2d(in_channels=hidden_units,
                  out_channels=hidden_units,
                  kernel_size=3,
                  stride=1,
                  padding=1),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size=2)
    )
    self.classifier = nn.Sequential(
        nn.Flatten(),
        nn.Linear(in_features=hidden_units*64*64,
                  out_features=output_shape)
    )

  def forward(self, x):
    x = self.conv_block_1(x)
    #print(x.shape)
    x = self.conv_block_2(x)
    #print(x.shape)
    x = self.classifier(x)
    return x

# %%
model = CNNv1(input_shape=3,
              hidden_units=102,
              output_shape=102).to(device)
print(model)
# Out:
# CNNv1(
#   (conv_block_1): Sequential(
#     (0): Conv2d(3, 102, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(102, 102, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv_block_2): Sequential(
#     (0): Conv2d(102, 102, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(102, 102, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=417792, out_features=102, bias=True)
#   )
# )

# %%
#Loss function and optimiser
loss_fn = nn.CrossEntropyLoss()
#optimiser = torch.optim.SGD(model.parameters(),
#                            lr=lr,
#                            momentum=momentum,
#                            weight_decay=weight_decay,
#                            dampening=dampening)
optimiser = torch.optim.Adam(model.parameters(),
                             lr=lr,
                             weight_decay=weight_decay)

# %%
#Train the model using the training data
def train(dataloader, model, loss_fn, optimiser):
  size = len(dataloader.dataset)
  batches = len(dataloader)
  model.train()
  running_loss, running_corrects = 0, 0

  for batch, (X, y) in enumerate(dataloader):
    X, y = X.to(device), y.to(device)

    # Compute prediction error
    pred = model(X)
    loss = loss_fn(pred, y)

    running_loss += loss
    running_corrects += torch.count_nonzero(pred.argmax(1)==y)

    # Backpropagation
    loss.backward()
    optimiser.step()
    optimiser.zero_grad()

  ave_loss = running_loss/batches
  corrects = running_corrects/size

  print(f"Train Error: \nAccuracy: {(100*corrects):.2f}%, Avg loss: {ave_loss:.6f} \n")

  return ave_loss, corrects

# %%
#Validate the models progress using the validation data
def valTest(dataloader, model, loss_fn, split):
  size = len(dataloader.dataset)
  batches = len(dataloader)
  model.eval()
  running_loss, running_corrects = 0, 0

  with torch.inference_mode():
    for X, y in dataloader:
      X, y = X.to(device), y.to(device)
      pred = model(X)
      loss = loss_fn(pred,y)

      running_loss += loss
      running_corrects += torch.count_nonzero(pred.argmax(1)==y)

  ave_loss = running_loss/batches
  corrects = running_corrects/size

  print(f"{split} Error: \n Accuracy: {(100*corrects):.2f}%, Avg loss: {ave_loss:.6f} \n")

  return ave_loss, corrects

# %%
def pltHist(hist):
  plt.figure(figsize=(17,5))
  plt.subplot(121)
  plt.plot(hist['train_loss'],'-o')
  plt.plot(hist['val_loss'],'-o')
  plt.xlabel('epoch')
  plt.ylabel('loss')
  plt.legend(['Train','Val'])
  plt.title('Train vs Validation loss')

  plt.subplot(122)
  plt.plot(hist['train_accuracy'],'-o')
  plt.plot(hist['val_accuracy'],'-o')
  plt.xlabel('epoch')
  plt.ylabel('Accuracy')
  plt.legend(['Train','Val'])
  plt.title('Train vs Validation Accuracy')

# %%
def trainValLoop(model, loss_fn, optimiser, epochs):
  train_loss_hist = []
  train_acc_hist = []
  val_loss_hist = []
  val_acc_hist = []

  for epoch in range(epochs):
    print(f"Epoch {epoch+1}/{epochs} -------------------------------")
    train_loss, train_acc = train(train_dataloader, model, loss_fn, optimiser)
    val_loss, val_acc = valTest(val_dataloader, model, loss_fn, 'Validate')

    train_loss_hist.append(train_loss.cpu().detach().numpy())
    train_acc_hist.append(train_acc.cpu().cpu().detach().numpy())
    val_loss_hist.append(val_loss.cpu().detach().numpy())
    val_acc_hist.append(val_acc.cpu().detach().numpy())

  hist = {'train_loss':train_loss_hist, 'train_accuracy':train_acc_hist,
          'val_loss':val_loss_hist, 'val_accuracy':val_acc_hist}
  pltHist(hist)
  valTest(test_dataloader, model, loss_fn, 'Test')

# %%
trainValLoop(model, loss_fn, optimiser, epochs)
# Out:
# Epoch 1/50 -------------------------------
# Train Error:
# Accuracy: 0.39%, Avg loss: 4.707381
#
# Validate Error:
#  Accuracy: 4.51%, Avg loss: 4.584415
#
# Epoch 2/50 -------------------------------
# Train Error:
# Accuracy: 5.49%, Avg loss: 4.541984
#
# Validate Error:
#  Accuracy: 8.04%, Avg loss: 4.414665
#
# Epoch 3/50 -------------------------------
# Train Error:
# Accuracy: 9.90%, Avg loss: 4.236340
#
# Validate Error:
#  Accuracy: 11.67%, Avg loss: 3.968213
#
# Epoch 4/50 -------------------------------
# Train Error:
# Accuracy: 20.00%, Avg loss: 3.700528
#
# Validate Error:
#  Accuracy: 14.22%, Avg loss: 3.669757
#
# Epoch 5/50 -------------------------------
# Train Error:
# Accuracy: 33.53%, Avg loss: 3.046933
#
# Validate Error:
#  Accuracy: 15.39%, Avg loss: 3.727997
#
# Epoch 6/50 -------------------------------
# Train Error:
# Accuracy: 43.92%, Avg loss: 2.682597
#
# Validate Error:
#  Accuracy: 18.82%, Avg loss: 3.599595
#
# Epoch 7/50 -------------------------------
# Train Error:
# Accuracy: 52.06%, Avg loss: 2.273307
#
# Validate Error:
#  Accuracy: 17.55%, Avg loss: 3.721128
#
# Epoch 8/50 -------------------------------
# Train Error:
# Accuracy: 56.37%, Avg loss: 2.026669
#
# Validate Error:
#  Accuracy: 19.22%, Avg loss: 3.702792
#
# Epoch 9/50 -------------------------------
# Train Error:
# Accuracy: 64.31%, Avg loss: 1.889432
#
# Validate Error:
#  Accuracy: 18.43%, Avg loss: 3.865100
#
# Epoch 10/50 -------------------------------
# Train Error:
# Accuracy: 64.12%, Avg loss: 1.726249
#
# Validate Error:
#  Accuracy: 19.61%, Avg loss: 3.796851
#
# Epoch 11/50 -------------------------------
# Train Error:
# Accuracy: 67.65%, Avg loss: 1.694367
#
# Validate Error:
#  Accuracy: 20.39%, Avg loss: 3.797835
#
# Epoch 12/50 -------------------------------
# Train Error:
# Accuracy: 67.84%, Avg loss: 1.630519
#
# Validate Error:
#  Accuracy: 20.39%, Avg loss: 3.787017
#
# Epoch 13/50 -------------------------------
# Train Error:
# Accuracy: 69.80%, Avg loss: 1.581645
#
# Validate Error:
#  Accuracy: 19.12%, Avg loss: 3.862520
#
# Epoch 14/50 -------------------------------
# Train Error:
# Accuracy: 68.53%, Avg loss: 1.610230
#
# Validate Error:
#  Accuracy: 19.71%, Avg loss: 3.894731
#
# Epoch 15/50 -------------------------------
# Train Error:
# Accuracy: 71.18%, Avg loss: 1.552487
#
# Validate Error:
#  Accuracy: 19.51%, Avg loss: 3.840518
#
# Epoch 16/50 -------------------------------
# Train Error:
# Accuracy: 72.94%, Avg loss: 1.371606
#
# Validate Error:
#  Accuracy: 20.10%, Avg loss: 3.930954
#
# Epoch 17/50 -------------------------------
# Train Error:
# Accuracy: 73.43%, Avg loss: 1.356431
#
# Validate Error:
#  Accuracy: 20.20%, Avg loss: 3.987735
#
# Epoch 18/50 -------------------------------
# Train Error:
# Accuracy: 71.76%, Avg loss: 1.457565
#
# Validate Error:
#  Accuracy: 19.80%, Avg loss: 3.898870
#
# Epoch 19/50 -------------------------------
# Train Error:
# Accuracy: 74.12%, Avg loss: 1.365224
#
# Validate Error:
#  Accuracy: 20.49%, Avg loss: 3.921755
#
# Epoch 20/50 -------------------------------
# Train Error:
# Accuracy: 76.18%, Avg loss: 1.208962
#
# Validate Error:
#  Accuracy: 22.25%, Avg loss: 3.856412
#
# Epoch 21/50 -------------------------------
# Train Error:
# Accuracy: 74.41%, Avg loss: 1.289643
#
# Validate Error:
#  Accuracy: 19.80%, Avg loss: 4.010813
#
# Epoch 22/50 -------------------------------
# Train Error:
# Accuracy: 75.39%, Avg loss: 1.392149
#
# Validate Error:
#  Accuracy: 20.20%, Avg loss: 3.935895
#
# Epoch 23/50 -------------------------------
# Train Error:
# Accuracy: 76.18%, Avg loss: 1.332422
#
# Validate Error:
#  Accuracy: 20.98%, Avg loss: 3.839570
#
# Epoch 24/50 -------------------------------
# Train Error:
# Accuracy: 73.43%, Avg loss: 1.283462
#
# Validate Error:
#  Accuracy: 19.80%, Avg loss: 3.869758
#
# Epoch 25/50 -------------------------------
# Train Error:
# Accuracy: 77.16%, Avg loss: 1.203879
#
# Validate Error:
#  Accuracy: 21.96%, Avg loss: 3.868438
#
# Epoch 26/50 -------------------------------
# Train Error:
# Accuracy: 75.49%, Avg loss: 1.226006
#
# Validate Error:
#  Accuracy: 18.73%, Avg loss: 3.996570
#
# Epoch 27/50 -------------------------------
# Train Error:
# Accuracy: 75.98%, Avg loss: 1.190047
#
# Validate Error:
#  Accuracy: 21.27%, Avg loss: 3.882815
#
# Epoch 28/50 -------------------------------
# Train Error:
# Accuracy: 76.37%, Avg loss: 1.217107
#
# Validate Error:
#  Accuracy: 21.27%, Avg loss: 3.876333
#
# Epoch 29/50 -------------------------------
# Train Error:
# Accuracy: 75.69%, Avg loss: 1.204972
#
# Validate Error:
#  Accuracy: 20.00%, Avg loss: 3.948604
#
# Epoch 30/50 -------------------------------
# Train Error:
# Accuracy: 75.69%, Avg loss: 1.200061
#
# Validate Error:
#  Accuracy: 22.84%, Avg loss: 3.791951
#
# Epoch 31/50 -------------------------------
# Train Error:
# Accuracy: 78.04%, Avg loss: 1.128245
#
# Validate Error:
#  Accuracy: 19.80%, Avg loss: 3.927815
#
# Epoch 32/50 -------------------------------
# Train Error:
# Accuracy: 77.65%, Avg loss: 1.048549
#
# Validate Error:
#  Accuracy: 21.86%, Avg loss: 3.953978
#
# Epoch 33/50 -------------------------------
# Train Error:
# Accuracy: 77.06%, Avg loss: 1.178469
#
# Validate Error:
#  Accuracy: 21.67%, Avg loss: 3.819789
#
# Epoch 34/50 -------------------------------
# Train Error:
# Accuracy: 78.24%, Avg loss: 1.099148
#
# Validate Error:
#  Accuracy: 22.84%, Avg loss: 3.857432
#
# Epoch 35/50 -------------------------------
# Train Error:
# Accuracy: 76.76%, Avg loss: 1.156575
#
# Validate Error:
#  Accuracy: 22.65%, Avg loss: 3.869713
#
# Epoch 36/50 -------------------------------
# Train Error:
# Accuracy: 77.16%, Avg loss: 1.144574
#
# Validate Error:
#  Accuracy: 22.16%, Avg loss: 3.777205
#
# Epoch 37/50 -------------------------------
# Train Error:
# Accuracy: 77.06%, Avg loss: 1.119843
#
# Validate Error:
#  Accuracy: 21.86%, Avg loss: 3.778927
#
# Epoch 38/50 -------------------------------
# Train Error:
# Accuracy: 80.00%, Avg loss: 1.018614
#
# Validate Error:
#  Accuracy: 22.84%, Avg loss: 3.846587
#
# Epoch 39/50 -------------------------------
# Train Error:
# Accuracy: 79.02%, Avg loss: 1.022867
#
# Validate Error:
#  Accuracy: 22.45%, Avg loss: 3.930032
#
# Epoch 40/50 -------------------------------
# Train Error:
# Accuracy: 78.53%, Avg loss: 1.087397
#
# Validate Error:
#  Accuracy: 22.16%, Avg loss: 3.942766
#
# Epoch 41/50 -------------------------------
# Train Error:
# Accuracy: 79.61%, Avg loss: 1.024199
#
# Validate Error:
#  Accuracy: 21.18%, Avg loss: 4.003415
#
# Epoch 42/50 -------------------------------
# Train Error:
# Accuracy: 78.24%, Avg loss: 1.104895
#
# Validate Error:
#  Accuracy: 20.69%, Avg loss: 3.843892
#
# Epoch 43/50 -------------------------------
# Train Error:
# Accuracy: 78.14%, Avg loss: 1.072147
#
# Validate Error:
#  Accuracy: 22.25%, Avg loss: 3.900546
#
# Epoch 44/50 -------------------------------
# Train Error:
# Accuracy: 79.31%, Avg loss: 1.020569
#
# Validate Error:
#  Accuracy: 21.37%, Avg loss: 3.812585
#
# Epoch 45/50 -------------------------------
# Train Error:
# Accuracy: 80.69%, Avg loss: 0.932663
#
# Validate Error:
#  Accuracy: 22.25%, Avg loss: 3.797061
#
# Epoch 46/50 -------------------------------
# Train Error:
# Accuracy: 79.51%, Avg loss: 1.022236
#
# Validate Error:
#  Accuracy: 21.08%, Avg loss: 4.020057
#
# Epoch 47/50 -------------------------------
# Train Error:
# Accuracy: 79.41%, Avg loss: 0.919096
#
# Validate Error:
#  Accuracy: 21.76%, Avg loss: 3.993466
#
# Epoch 48/50 -------------------------------
# Train Error:
# Accuracy: 77.94%, Avg loss: 1.075182
#
# Validate Error:
#  Accuracy: 21.96%, Avg loss: 3.855053
#
# Epoch 49/50 -------------------------------
# Train Error:
# Accuracy: 80.20%, Avg loss: 0.950487
#
# Validate Error:
#  Accuracy: 22.06%, Avg loss: 3.849394
#
# Epoch 50/50 -------------------------------
# Train Error:
# Accuracy: 80.39%, Avg loss: 0.970996
#
# Validate Error:
#  Accuracy: 20.69%, Avg loss: 3.966590
#
# Test Error:
#  Accuracy: 19.34%, Avg loss: 4.245161

# %%
#Stops Google stealing my credits
runtime.unassign()
